# %%
import pandas as pd
titanic=pd.read_csv('C:/Users/s/Downloads/titanic_train (3) (1).csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Details=pd.DataFrame.from_dict(Employee)
Details
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/276785066.py in <module>
# ----> 1 Details=pd.DataFrame.from_dict(Employee)
#       2 Details
#
# NameError: name 'Employee' is not defined

# %%
Details.to_csv('my deatails.csv')

# %%
import numpy as np
ar=np.array([['mango','orange','pawpaw','lemon','melon'],[1,2,3,4,5]], dtype=object)
ar

# %%
# Transpose
fruit=pd.DataFrame(ar).T
fruit

# %%
#renaming columns
fruit=pd.DataFrame(ar).T
fruit=fruit.rename(columns={0:'fruits',1:'price'})
fruit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/4209572885.py in <module>
#       1 #renaming columns
# ----> 2 fruit=pd.DataFrame(ar).T
#       3 fruit=fruit.rename(columns={0:'fruits',1:'price'})
#       4 fruit
#
# NameError: name 'ar' is not defined

# %%
import pandas as pd
titanic=pd.read_csv('C:/Users/TIMOH/Downloads/titanic_train (1).csv')
titanic

# %%
# square root
from math import sqrt
x=25
y=sqrt(x)
y

# %%
# Exploring pandas dataframe
import pandas as pd
orders = pd.read_table('http://bit.ly/chiporders')
orders

# %%
'http://bit.ly/imdbratings'

'http://bit.ly/uforeports'

# %%
orders.tail()# last 5 rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/3427858375.py in <module>
# ----> 1 orders.tail()# last 5 rows
#
# NameError: name 'orders' is not defined

# %%
orders.info()

# %%
11:47
http://bit.ly/movieusers
11:47
'http://bit.ly/uforeports'
11:48
'http://bit.ly/uforeports'
11:48
'http://bit.ly/imdbratings'
# Out:
#   File "C:\Users\TIMOH\AppData\Local\Temp/ipykernel_11340/3153444396.py", line 1
#     11:47
#     ^
# SyntaxError: illegal target for annotation

# %%
orders.describe()

# %%
orders['item_name'].unique()

# %%
orders.describe(include='object')

# %%
orders.choice_description.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/601481731.py in <module>
# ----> 1 orders.choice_description.value_counts()
#
# NameError: name 'orders' is not defined

# %%
## Importing json file
import pandas as pd
modcloth=pd.read_json('C:/Users/TIMOH/Downloads/modcloth_final_data.json',lines=True)
modcloth

# %%
# checking info
modcloth.info()

# %%
modcloth.columns

# %%
# selecting part of columns
mod1=modcloth[['item_id', 'waist', 'size']]
mod1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/4177541604.py in <module>
#       1 # selecting part of columns
# ----> 2 mod1=modcloth[['item_id', 'waist', 'size']]
#       3 mod1
#
# NameError: name 'modcloth' is not defined

# %% [markdown]
# # Commands with and without parentheses

# %%
# commands without parenthesis
modcloth.shape

# %%
# checking column names
modcloth.columns

# %%
# checking data types
modcloth.dtypes

# %%
# commands with parenthesis
#checking information
modcloth.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/3361717913.py in <module>
#       1 # commands with parenthesis
#       2 #checking information
# ----> 3 modcloth.info()
#
# NameError: name 'modcloth' is not defined

# %%
modcloth.review_summary.value_counts()

# %%
mod1=modcloth.dropna()
mod1[mod1.review_summary.str.contains('I love')]

# %%
# checking descriptive statistics
modcloth.describe()

# %%
modcloth.describe(include='object')

# %%
modcloth.describe(include=['object','float','int'])

# %%
# dropping column
mod1=modcloth.drop('waist',axis=1)
mod1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/2389949133.py in <module>
#       1 # dropping column
# ----> 2 mod1=modcloth.drop('waist',axis=1)
#       3 mod1.head()
#
# NameError: name 'modcloth' is not defined

# %%
# dropping multiple columns
mod1=modcloth.drop(['waist','size'],axis=1)
mod1.head()

# %%
# checking missing values
modcloth.isna().sum()

# %%
modcloth.columns

# %%
# selecting pandas series
modcloth.hips.head()

# %%
modcloth['cup size'].head()

# %%
movies=pd.read_table('http://bit.ly/imdbratings',sep=',')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# # sorting pandas dataframe

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies.genre
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: object

# %%
# sorting pandas series
movies.genre.sort_values()
# Out:
# 152     Action
# 753     Action
# 619     Action
# 129     Action
# 871     Action
#         ...
# 263    Western
# 236    Western
# 119    Western
# 421    Western
# 704    Western
# Name: genre, Length: 979, dtype: object

# %%
# sorting dataframe based on column
movies.sort_values('genre').head(20)
# Out:
#      star_rating                               title content_rating   genre  \
# 152          8.2                      V for Vendetta              R  Action
# 753          7.6                Escape from Alcatraz             PG  Action
# 619          7.7                    Forbidden Planet         PASSED  Action
# 129          8.3                                 Ran              R  Action
# 871          7.5                                  X2          PG-13  Action
# 699          7.6                   The Fifth Element          PG-13  Action
# 261          8.1                         Elite Squad              R  Action
# 135          8.3                                Heat              R  Action
# 138          8.3                            Die Hard              R  Action
# 858          7.5  Sherlock Holmes: A Game of Shadows          PG-13  Action
# 623          7.7      Dawn of the Planet of the Apes          PG-13  Action
# ...

# %% [markdown]
# # Renaming columns

# %%
import pandas as pd
UFO=pd.read_csv('http://bit.ly/uforeports')
UFO.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
UFO.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
# rename function
uf=UFO.rename(columns={'Colors Reported':'colorsreported','Shape Reported':'shapesreported'})
uf
# Out:
#                        City colorsreported shapesreported State  \
# 0                    Ithaca            NaN       TRIANGLE    NY
# 1               Willingboro            NaN          OTHER    NJ
# 2                   Holyoke            NaN           OVAL    CO
# 3                   Abilene            NaN           DISK    KS
# 4      New York Worlds Fair            NaN          LIGHT    NY
# ...                     ...            ...            ...   ...
# 18236            Grant Park            NaN       TRIANGLE    IL
# 18237           Spirit Lake            NaN           DISK    IA
# 18238           Eagle River            NaN            NaN    WI
# 18239           Eagle River            RED          LIGHT    WI
# 18240                  Ybor            NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
# renamimg
uf.columns=['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time']

# %%
uf.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# interchanging columns
uf.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
uf1=uf[['State', 'Colors_Reported','Time' , 'City','Shape_Reported']]
uf1
# Out:
#       State Colors_Reported              Time                  City  \
# 0        NY             NaN    6/1/1930 22:00                Ithaca
# 1        NJ             NaN   6/30/1930 20:00           Willingboro
# 2        CO             NaN   2/15/1931 14:00               Holyoke
# 3        KS             NaN    6/1/1931 13:00               Abilene
# 4        NY             NaN   4/18/1933 19:00  New York Worlds Fair
# ...     ...             ...               ...                   ...
# 18236    IL             NaN  12/31/2000 23:00            Grant Park
# 18237    IA             NaN  12/31/2000 23:00           Spirit Lake
# 18238    WI             NaN  12/31/2000 23:45           Eagle River
# 18239    WI             RED  12/31/2000 23:45           Eagle River
# 18240    FL             NaN  12/31/2000 23:59                  Ybor
#
#       Shape_Reported
# 0           TRIANGLE
# 1              OTHER
# 2               OVAL
# 3               DISK
# 4              LIGHT
# ...

# %%
# checking unique values
uf.nunique()
# Out:
# City                6476
# Colors_Reported       27
# Shape_Reported        27
# State                 52
# Time               16145
# dtype: int64

# %%
cat=uf.select_dtypes(include='object')
cat
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
cat.nunique()
# Out:
# City                6476
# Colors_Reported       27
# Shape_Reported        27
# State                 52
# Time               16145
# dtype: int64

# %%
# replacing white space with underscore
UFO.columns=UFO.columns.str.replace(' ','_')
UFO
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# # applying filter criteria to pandas dataframe

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 67      1
# 195     1
# 76      1
# 66      1
# 205     1
# Name: duration, Length: 133, dtype: int64

# %%
mytime=[]
for j in movies['duration']:
    if j>120:
        mytime.append(True)
    else:
        mytime.append(False)
mytime
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
# ...

# %%
movies1=movies[mytime]
movies1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
movies[movies.duration>=120]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
adv=[]
for j in movies['genre']:
    if j=='Adventure':
        adv.append(True)
    else:
        adv.append(False)
adv
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
movies1=movies[adv]
movies1
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 54           8.5                                 Back to the Future
# ..           ...                                                ...
# 936          7.4                                          True Grit
# 937          7.4                                          Labyrinth
# 943          7.4                                    The Bucket List
# 953          7.4                              The NeverEnding Story
# 975          7.4                        Back to the Future Part III
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
ad=movies[adv]
ad
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 54           8.5                                 Back to the Future
# ..           ...                                                ...
# 936          7.4                                          True Grit
# 937          7.4                                          Labyrinth
# 943          7.4                                    The Bucket List
# 953          7.4                              The NeverEnding Story
# 975          7.4                        Back to the Future Part III
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
len(ad)
# Out:
# 75

# %%
movies[movies.content_rating=='PG-13']
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# ..           ...                                                ...
# 964          7.4                                            Lincoln
# 965          7.4                                          Limitless
# 966          7.4                                 The Simpsons Movie
# 973          7.4                              The Cider House Rules
# 976          7.4    Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 7            PG-13  Adventure       201
# ...

# %%
mov=movies[(movies.content_rating=='R')&(movies.duration>162)&(movies.genre=='Crime')]
mov
# Out:
#      star_rating                        title content_rating  genre  duration  \
# 1            9.2                The Godfather              R  Crime       175
# 2            9.1       The Godfather: Part II              R  Crime       200
# 40           8.5               The Green Mile              R  Crime       189
# 78           8.4  Once Upon a Time in America              R  Crime       229
# 115          8.3                     Scarface              R  Crime       170
# 300          8.0                     Dogville              R  Crime       178
# 828          7.5            Gangs of New York              R  Crime       167
#
#                                            actors_list
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 40   [u'Tom Hanks', u'Michael Clarke Duncan', u'Dav...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 115  [u'Al Pacino', u'Michelle Pfeiffer', u'Steven ...
# ...

# %%
len(mov)
# Out:
# 7

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies['actors_list'].value_counts()
# Out:
# [u'Daniel Radcliffe', u'Emma Watson', u'Rupert Grint']        6
# [u'Mark Hamill', u'Harrison Ford', u'Carrie Fisher']          3
# [u'Ian McKellen', u'Martin Freeman', u'Richard Armitage']     2
# [u'Michael J. Fox', u'Christopher Lloyd', u'Lea Thompson']    2
# [u'Tom Hanks', u'Tim Allen', u'Joan Cusack']                  2
#                                                              ..
# [u'Natalie Portman', u'Mila Kunis', u'Vincent Cassel']        1
# [u'Brad Garrett', u'Lou Romano', u'Patton Oswalt']            1
# [u'John Wayne', u'Jeffrey Hunter', u'Vera Miles']             1
# [u'Brie Larson', u'Frantz Turner', u'John Gallagher Jr.']     1
# [u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']       1
# Name: actors_list, Length: 969, dtype: int64

# %%
movies[(movies.genre.isin(['Drama','Adventure','Action']))&(movies.star_rating>8.5)]
# Out:
#     star_rating                                              title  \
# 3           9.0                                    The Dark Knight
# 5           8.9                                       12 Angry Men
# 7           8.9      The Lord of the Rings: The Return of the King
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# 13          8.8                                       Forrest Gump
# 14          8.8              The Lord of the Rings: The Two Towers
# 15          8.7                                       Interstellar
# 16          8.7                    One Flew Over the Cuckoo's Nest
# 17          8.7                                      Seven Samurai
# 19          8.7                                          Star Wars
# ...

# %%
movies.actors_list.value_counts()
# Out:
# [u'Daniel Radcliffe', u'Emma Watson', u'Rupert Grint']        6
# [u'Mark Hamill', u'Harrison Ford', u'Carrie Fisher']          3
# [u'Ian McKellen', u'Martin Freeman', u'Richard Armitage']     2
# [u'Michael J. Fox', u'Christopher Lloyd', u'Lea Thompson']    2
# [u'Tom Hanks', u'Tim Allen', u'Joan Cusack']                  2
#                                                              ..
# [u'Natalie Portman', u'Mila Kunis', u'Vincent Cassel']        1
# [u'Brad Garrett', u'Lou Romano', u'Patton Oswalt']            1
# [u'John Wayne', u'Jeffrey Hunter', u'Vera Miles']             1
# [u'Brie Larson', u'Frantz Turner', u'John Gallagher Jr.']     1
# [u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']       1
# Name: actors_list, Length: 969, dtype: int64

# %%
movies[(movies.actors_list=="[u'Daniel Radcliffe', u'Emma Watson', u'Rupert Grint']")&(movies.duration<120)&(movies.genre.isin(['Adventure','Drama','Action']))]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
input_string = input()
print('Hello, World.')
print(str(input_string))
# Out:
# hr
# Hello, World.
# hr

# %% [markdown]
# # Use of strings in Pandas

# %%
k='john'
x=k.upper()
x
# Out:
# 'JOHN'

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
import pandas as pd
orders = pd.read_table('http://bit.ly/chiporders')
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
orders.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
# using string to select some values in data
orders[orders.item_name.str.contains('Salad')]
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 135         60         2  Chicken Salad Bowl
# 186         83         1   Veggie Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 250        109         1       Chicken Salad
# ...        ...       ...                 ...
# 4573      1818         1   Veggie Salad Bowl
# 4580      1822         1  Chicken Salad Bowl
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 44    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 186   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50
# 250   [Roasted Chili Corn Salsa (Medium), [Black Bea...    $10.98
# ...

# %%
# using string to remove special characters
orders['item_price']=orders['item_price'].str.replace('$','',regex=True)
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
# removing square brackects[]
orders['choice_description']=orders['choice_description'].str.replace('[\[\]]','',regex=True)
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                         Clementine      3.39
# 2                                              Apple      3.39
# 3                                                NaN      2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...     16.98

# %% [markdown]
# # converting datatypes (astype)

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders['item_price']=orders['item_price'].astype(float)
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
orders['item_price'].astype(int)
# Out:
# 0        2
# 1        3
# 2        3
# 3        2
# 4       16
#         ..
# 4617    11
# 4618    11
# 4619    11
# 4620     8
# 4621     8
# Name: item_price, Length: 4622, dtype: int32

# %%
orders.item_name.str.contains('Tomato')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: item_name, Length: 4622, dtype: bool

# %%
orders[orders.item_name.str.contains('Tomato')]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 0           2.39
# 25          2.39
# 55          2.39
# ...

# %% [markdown]
# # convert item price to an integer and rename it as item_p,then compare the mean of item_price(float)and the average of item_p(integer)

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                         Clementine        3.39
# 2                                              Apple        3.39
# 3                                                NaN        2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...       16.98

# %%
orders['item_p']=orders['item_price'].astype(int)
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  item_p
# 0                                                   NaN        2.39       2
# ...

# %%
orders['item_price'].mean()
# Out:
# 7.464335785374397

# %%
orders['item_p'].mean()
# Out:
# 6.934660320207702

# %% [markdown]
# # using groupby  in pandas

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
asia=drinks[drinks.continent=='Asia']
asia.wine_servings.mean()
# Out:
# 9.068181818181818

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
asia.wine_servings.agg(['count','mean','std','max'])
# Out:
# count     44.000000
# mean       9.068182
# std       21.667034
# max      123.000000
# Name: wine_servings, dtype: float64

# %%
drinks.groupby('continent').wine_servings.mean()
# Out:
# continent
# Africa            16.264151
# Asia               9.068182
# Europe           142.222222
# North America     24.521739
# Oceania           35.625000
# South America     62.416667
# Name: wine_servings, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
drinks.groupby('continent')['beer_servings', 'spirit_servings', 'wine_servings',
 'total_litres_of_pure_alcohol'].mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
drinks.groupby(['continent','country'])['beer_servings', 'spirit_servings', 'wine_servings',
 'total_litres_of_pure_alcohol'].mean()
# Out:
#                             beer_servings  spirit_servings  wine_servings  \
# continent     country
# Africa        Algeria                25.0              0.0           14.0
#               Angola                217.0             57.0           45.0
#               Benin                  34.0              4.0           13.0
#               Botswana              173.0             35.0           35.0
#               Burkina Faso           25.0              7.0            7.0
# ...                                   ...              ...            ...
# South America Paraguay              213.0            117.0           74.0
#               Peru                  163.0            160.0           21.0
#               Suriname              128.0            178.0            7.0
#               Uruguay               115.0             35.0          220.0
#               Venezuela             333.0            100.0            3.0
#
#                             total_litres_of_pure_alcohol
# ...

# %%
drinks.groupby('continent')['beer_servings', 'spirit_servings', 'wine_servings',
 'total_litres_of_pure_alcohol'].mean().plot.bar();

# %%
drinks.groupby('continent')['beer_servings', 'spirit_servings', 'wine_servings',
 'total_litres_of_pure_alcohol'].agg(['mean','count','median','std','max'])
# Out:
#               beer_servings                              spirit_servings  \
#                        mean count median        std  max            mean
# continent
# Africa            61.471698    53   32.0  80.557816  376       16.339623
# Asia              37.045455    44   17.5  49.469725  247       60.840909
# Europe           193.777778    45  219.0  99.631569  361      132.555556
# North America    145.434783    23  143.0  79.621163  285      165.739130
# Oceania           89.687500    16   52.5  96.641412  306       58.437500
# South America    175.083333    12  162.5  65.242845  333      114.750000
#
#                                            wine_servings               \
#               count median        std  max          mean count median
# continent
# Africa           53    3.0  28.102794  152     16.264151    53    2.0
# Asia             44   16.0  84.362160  326      9.068182    44    1.0
# Europe           45  122.0  77.589115  373    142.222222    45  128.0
# ...

# %%
drinks.groupby('continent')['beer_servings', 'spirit_servings'].agg(['mean','count','median','std','max'])
# Out:
#               beer_servings                              spirit_servings  \
#                        mean count median        std  max            mean
# continent
# Africa            61.471698    53   32.0  80.557816  376       16.339623
# Asia              37.045455    44   17.5  49.469725  247       60.840909
# Europe           193.777778    45  219.0  99.631569  361      132.555556
# North America    145.434783    23  143.0  79.621163  285      165.739130
# Oceania           89.687500    16   52.5  96.641412  306       58.437500
# South America    175.083333    12  162.5  65.242845  333      114.750000
#
#
#               count median        std  max
# continent
# Africa           53    3.0  28.102794  152
# Asia             44   16.0  84.362160  326
# Europe           45  122.0  77.589115  373
# North America    23  137.0  94.993884  438
# Oceania          16   37.0  70.504817  254
# South America    12  108.5  77.077440  302

# %% [markdown]
#  # crosstabulation

# %%
data=pd.read_csv('C:/Users/TIMOH/Downloads/LOANDATA(1).csv')
data.head()
# Out:
#    Unnamed: 0  Customer Id  Date of Birth         DOB age Province District  \
# 0           0       846078       19910611   11/6/1991  28      NaN      NaN
# 1           1       846100       19910321  21/03/1991  28      NaN      NaN
# 2           2       851947       19880209    9/2/1988  31      NaN      NaN
# 3           3      1333968       19841006   6/10/1984  34      NaN      NaN
# 4           4       862504       19780423  23/04/1978  41      NaN      NaN
#
#    Customer Branch  Principal amt  Paid principal  ...  Paid Tax  \
# 0               40           1000            1000  ...         0
# 1               40           1000            1000  ...         0
# 2               40           1000            1000  ...         0
# 3               40           1000            1000  ...         0
# 4               46           1000            1000  ...         0
#
#    Previous Days  Overdue Days  Effective Date  Maturity Date  \
# ...

# %%
import pandas as pd
titanic=pd.read_csv('C:/Users/TIMOH/Downloads/titanic_train (1).csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
pd.crosstab(titanic.Survived,titanic.Pclass)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(titanic.Survived,titanic.Sex,normalize=True)
# Out:
# Sex         female      male
# Survived
# 0         0.090909  0.525253
# 1         0.261504  0.122334

# %%
titanic.groupby('Sex').Fare.mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
pd.crosstab(titanic.Pclass,titanic.Sex)
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
titanic.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic.groupby('Sex')['Fare','Age'].mean()
# Out:
#              Fare        Age
# Sex
# female  44.479818  27.915709
# male    25.523893  30.726645

# %%
((titanic.isnull().sum()/len(titanic))*100).round(2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %% [markdown]
# # matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
covid=pd.read_csv('C:/Users/TIMOH/Downloads/covid_19_india.csv')
covid
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1  1/30/2020  6:00 PM               Kerala                       1
# 1          2  1/31/2020  6:00 PM               Kerala                       1
# 2          3   2/1/2020  6:00 PM               Kerala                       2
# 3          4   2/2/2020  6:00 PM               Kerala                       3
# 4          5   2/3/2020  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106  8/11/2021  8:00 AM            Telangana                       -
# 18106  18107  8/11/2021  8:00 AM              Tripura                       -
# 18107  18108  8/11/2021  8:00 AM          Uttarakhand                       -
# 18108  18109  8/11/2021  8:00 AM        Uttar Pradesh                       -
# 18109  18110  8/11/2021  8:00 AM          West Bengal                       -
#
# ...

# %%
state=pd.read_csv('C:/Users/TIMOH/Downloads/statewise_tested_numbers_data.csv')
state.head(3)
# Out:
#    Updated On                        State  Total Tested Tag (Total Tested)  \
# 0  17/04/2020  Andaman and Nicobar Islands        1403.0       Samples Sent
# 1  24/04/2020  Andaman and Nicobar Islands        2679.0       Samples Sent
# 2  27/04/2020  Andaman and Nicobar Islands        2848.0       Samples Sent
#
#    Positive Negative  Unconfirmed  Cumulative People In Quarantine  \
# 0      12.0     1210        181.0                              NaN
# 1      27.0      NaN        246.0                              NaN
# 2      33.0      NaN        106.0                              NaN
#
#    Total People Currently in Quarantine Tag (People in Quarantine)  ...  \
# 0                                   NaN                        NaN  ...
# 1                                 614.0              Institutional  ...
# 2                                 724.0              Institutional  ...
#
#    Corona Enquiry Calls  Num Calls State Helpline  \
# ...

# %% [markdown]
# # LINE CHART

# %%
state.columns
# Out:
# Index(['Updated On', 'State', 'Total Tested', 'Tag (Total Tested)', 'Positive',
#        'Negative', 'Unconfirmed', 'Cumulative People In Quarantine',
#        'Total People Currently in Quarantine', 'Tag (People in Quarantine)',
#        'Total People Released From Quarantine', 'People in ICU',
#        'People on Ventilators', 'Num Isolation Beds', 'Num ICU Beds',
#        'Num Ventilators', 'Total PPE', 'Total N95 Masks',
#        'Corona Enquiry Calls', 'Num Calls State Helpline', 'Source1',
#        'Source2', 'Source3', 'Test positivity rate', 'Tests per thousand',
#        'Tests per million', 'Tests per positive case',
#        'Population NCP 2019 Projection'],
#       dtype='object')

# %%
state['Updated On']=pd.to_datetime(state['Updated On'])

# %%
plt.figure(figsize=(20,10))
state.groupby('Updated On')['Total Tested'].median().plot()(color='r')
plt.title('Trend of total tested', fontsize=15)
plt.xlabel('Time' ,fontsize=13)
plt.ylabel('median of total tested' ,fontsize=13);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/330966923.py in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 state.groupby('Updated On')['Total Tested'].median().plot()(color='r')
#       3 plt.title('Trend of total tested', fontsize=15)
#       4 plt.xlabel('Time' ,fontsize=13)
#       5 plt.ylabel('median of total tested' ,fontsize=13);
#
# TypeError: 'AxesSubplot' object is not callable

# %%
state.columns

# %% [markdown]
# # Bar graph

# %%
plt.figure(figsize=(7,5))
state['Tag (People in Quarantine)'].value_counts(normalize=False).plot.bar(color=['m','r','b'])
plt.title('Distribution of People in Quarantine', fontsize=18)
plt.xlabel('People in Quarantine', fontsize=13)
plt.ylabel('Frequency of covid19 patients', fontsize=13);

# %%
plt.figure(figsize=(7,5))
explode=[0.05,0.05,0.05,0.05,0.05,0.05,0.05]
state['Tag (People in Quarantine)'].value_counts(normalize=False).plot(kind='pie',
                                                                       autopct='%1.1f%%',explode=explode,startangle=180);
plt.title('Distribution of People in Quarantine', fontsize=18)
plt.xlabel('')
plt.ylabel('');

# %%
state.Positive.plot(kind='hist',color='m')
plt.title('Distribution of covid 19 Positive cases');

# %% [markdown]
# # seaborn

# %% [markdown]
# # countplot

# %%
import seaborn as sb

# %%
state.nunique()

# %%
sb.countplot('Tag (Total Tested)',data=state);

# %%
plt.figure(figsize=(13,10))
sb.countplot(x='Tag (People in Quarantine)',hue='Tag (Total Tested)',data=state);

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
import numpy as np
df=pd.read_csv('C:/Users/TIMOH/Downloads/melb_data.csv')
df

# %%
df.nunique()

# %%
dm=df.loc[:,df.nunique()<10]
dm.nunique()

# %%
df.Bathroom.value_counts()

# %% [markdown]
# # countplot

# %%
sb.countplot(x='Rooms',hue='Type',data=df)

# %%
for h in dm.columns:
    plt.figure(figsize=(18,4))
    sb.countplot(x=h,hue='Rooms',data=df);

# %% [markdown]
# # Boxplot

# %%
# checking high cardinality values in numeric dataset
num=df.select_dtypes(include=np.number)#select numeric data
num1=num.loc[:,num.nunique()>10]#select numeric data with high cardinality greater than 10
num1.nunique()

# %%
num1.columns

# %%
nc=['Price', 'Distance', 'Postcode', 'Bedroom2', 'Car', 'Landsize',
       'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
       'Propertycount']

# %%
sb.boxplot(x='Method',y='Price',data=df)

# %%
plt.figure(figsize=(18,6))
sb.boxplot(x='Regionname',y='Price',data=df)

# %%
for k in nc:
    plt.figure(figsize=(18,6))
    sb.boxplot(x='Method',y=k,data=df)

# %% [markdown]
# # Barplot

# %%
nc

# %%
sb.barplot(x='Method',y='Price',data=df)

# %%
plt.figure(figsize=(18,5))
sb.barplot(x='Regionname',y='Price',data=df)

# %%
plt.figure(figsize=(18,5))
sb.barplot(x='Rooms',y='Landsize',data=df)

# %%
nc

# %%
for k in nc:
    plt.figure(figsize=(6,6))
    sb.barplot(x='Type',y=k,data=df)

# %% [markdown]
# # violin plot

# %%
sb.violinplot(x='Type',y='Price',data=df);

# %% [markdown]
# # catplot

# %%
sb.scatterplot(x='Price',y='Landsize',hue='Type',data=df);

# %%
sb.scatterplot(x='Distance',y='Price',hue='Regionname',data=df);

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(13,7))
sb.lineplot(x='Date',y='Price',data=df)

# %%
plt.figure(figsize=(13,7))
sb.catplot(x='Type',y='Price',kind='box',data=df)

# %%
plt.figure(figsize=(13,7))
sb.catplot(x='Method',hue='Type',kind='count',data=df)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
tit=pd.read_csv('C:/Users/TIMOH/Downloads/titanic_train (1).csv')
tit

# %%
sb.factorplot(x='Pclass',y='Age',data=tit);

# %%
sb.factorplot(x='Sex',y='Age', hue='Pclass',data=tit);

# %%
sb.catplot(x='Sex',y='Age', hue='Pclass', kind='point',data=tit);

# %%
sb.catplot(x='Sex',y='Age', hue='Survived', kind='point',data=tit);

# %%
sb.catplot(x='Pclass',y='Age', hue='Survived', kind='point',data=tit);

# %%
sb.catplot(x='Pclass',y='Age', hue='Survived', kind='bar',data=tit);

# %%
sb.catplot(x='Pclass',col='Embarked', hue='Survived', kind='count',data=tit);

# %% [markdown]
# # PLOTLY

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df=px.data.gapminder().query("continent=='Oceania'")
df

# %%
df.columns

# %%
fig=px.line(df,x="year",y="lifeExp",color="country")
fig.show()

# %%
fig=px.line(df,x="year",y="gdpPercap",color="country")
fig.show()

# %%
df = px.data.iris()
df.head()

# %%
df.species.unique()

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length", color='species')
fig.show()

# %%
fig=px.pie(df, values='species_id',names='species', title='species names for iris')
fig.show()

# %%
fig = px.violin(df, x='species', y="sepal_length", color='species')
fig.show()

# %%
import pandas as pd
us_cities = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv")
us_cities

# %%
fig=px.line_mapbox(us_cities, lat='lat',lon='lon',hover_name='City',hover_data=['State','Population'],color_discrete_sequence=['fuchsia'], zoom=4,height=500)
fig.update_layout(mapbox_style='open-street-map')
fig.update_layout(margin={'r':0,'t':0,'l':0,'b':0})
fig.show()

# %%
import pandas as pd
state=pd.read_csv('C:/Users/TIMOH/Downloads/statewise_tested_numbers_data.csv')
state.head(3)

# %%
state.info()

# %%
state['Updated On']=pd.to_datetime(state['Updated On'])

# %%
state.info()

# %%
import seaborn as sb
sb.kdeplot(data=state,x='Total Tested');

# %%
sb.displot(x='Total Tested',data=state);

# %%
state.columns

# %%
state.nunique()

# %%
import matplotlib.pyplot as plt
fig, ax=plt.subplots(3,2, figsize=(18,10))
ax[0,0].set_title('Trend of Positive cases')
sb.lineplot(x='Updated On',y='Positive',data=state,ax=ax[0,0])
ax[0,1].set_title('Tag(Total Tested) vs Total N95 Masks')
sb.barplot(x='Tag (Total Tested)',y='Total N95 Masks',data=state,ax=ax[0,1])
ax[1,0].set_title('Tag (People in Quarantine) vs Total Tested')
sb.boxplot(x='Tag (People in Quarantine)',y='Total Tested',data=state,ax=ax[1,0])
ax[1,1].set_title('Tag (People in Quarantine) vs Tag (Total Tested)')
sb.countplot(x='Tag (People in Quarantine)',hue='Tag (Total Tested)',data=state,ax=ax[1,1])
ax[2,0].set_title('Positive vs Tag (Total Tested)')
sb.kdeplot(x='Positive',hue='Tag (Total Tested)',data=state,ax=ax[2,0])
ax[2,1].set_title(' Tag (Total Tested) distribution')
sb.pieplot(x='Positive',hue='Tag (Total Tested)',data=state,ax=ax[2,0])

# %%
titanic=pd.read_csv('C:/Users/TIMOH/Downloads/titanic_train (1).csv')
titanic

# %%
titanic.columns

# %%
import matplotlib.pyplot as plt
fig, ax=plt.subplots(3,2, figsize=(18,10))
ax[0,0].set_title('Gender vs Survived')
sb.countplot(x='Sex',hue='Survived',data=titanic,ax=ax[0,0])
ax[0,0].legend(labels=['Did not survive','Survived'])
ax[0,1].set_title('Pclass vs Survived')
sb.countplot(x='Pclass',hue='Survived',data=titanic,ax=ax[0,1])
ax[0,1].legend(labels=['Did not survive','Survived'])
ax[0,1].set(xticklabels=['First Class','Second Class','Third Class'])
ax[0,1].set_xlabel('Passenger Class')
ax[0,1].set_ylabel('Number of Passengers')
ax[1,0].set_title('Fare Distribution')
sb.boxplot(x='Survived',y='Fare',data=titanic,ax=ax[1,0])
ax[1,0].set(xticklabels=['Did not Survive','Survived'])
ax[1,0].set_xlabel('survived')
ax[1,0].set_ylabel('')
plt.subplots_adjust(hspace=0.5)
ax[1,1].set_title('Tag (People in Quarantine) vs Tag (Total Tested)')
sb.countplot(x='Tag (People in Quarantine)',hue='Tag (Total Tested)',data=state,ax=ax[1,1])
ax[2,0].set_title('Positive vs Tag (Total Tested)')
sb.kdeplot(x='Positive',hue='Tag (Total Tested)',data=state,ax=ax[2,0])
ax[2,1].set_title('Trend of Total Tested')
state['Tag (People in Quarantine)'].value_counts().plot(kind='pie',autopct='%1.1f%%',subplots=True,ax=ax[2,1])
ax[2,1].set_ylabel('')

# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd
modcloth=pd.read_json('C:/Users/TIMOH/Downloads/modcloth_final_data.json',lines=True)
modcloth

# %%
import pandas as pd

# %%
# Example DataFrame
df = pd.DataFrame.from_dict({'Name'  : ['May21', 'James', 'Adi22', 'ADI', 'Girl90'],
                             'Volume': ['23s', 12, 11, 34, 56],
                             'Value' : [21321, 12311, 4435, 32454, 654654],
                            'text': ['This is ni89ce','Its pretty!', 'Its pretty','Its Pretty','this is nice']})
print(df)

# %%
df.nunique()

# %%
df.dtypes

# %% [markdown]
# # Handling Inconsistencies

# %%
# converting string values to lower cases
df=df.applymap(lambda x: x.lower() if type(x)==str else x)
df

# %%
df['Name1']=df['Name'].str.replace('\d+','')
df

# %%
def removedigits(s):
    return ''.join([x for x in s if not x.isdigit()])
df["Nam"]=df['Name'].apply(removedigits)
print(df)

# %%
df=df.drop(['Name1','Nam'],1)
df

# %%
df['Name1']=df['Name'].str.replace('\d+','')
df['text']=df['text'].str.replace('\d+','')
df

# %%
df.nunique()

# %%
# removing special characters
df['text']=df['text'].str.replace('[!,#,&,$,@]','',regex=True)
df

# %%
# removing string in numeric
df[['Volume']]=df[['Volume']].apply(pd.to_numeric, errors='coerce')
print(df)

# %%
import numpy as np
df[np.isfinite(pd.to_numeric(df.Volume, errors="coerce"))]

# %% [markdown]
# # FEATURE ENGINEERING

# %%
import pandas as pd
titanic=pd.read_csv('C:/Users/TIMOH/Downloads/titanic_train (1).csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#select columns with low cardinality
low=titanic.loc[:,titanic.nunique()<10]
low.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='object')

# %%
cols=titanic.select_dtypes(include='object')
cols.columns
# Out:
# Index(['Name'], dtype='object')

# %%
cols.nunique()
# Out:
# Name    891
# dtype: int64

# %%
# missing values
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic['Age']=titanic['Age'].fillna(titanic['Age'].median())
titanic['Age'].isnull().sum()
# Out:
# 0

# %%
titanic['Embarked']=titanic['Embarked'].fillna(titanic['Embarked'].mode()[0])
titanic['Embarked'].isnull().sum()
# Out:
# 0

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
cols.columns
# Out:
# Index(['Name'], dtype='object')

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
tit=titanic.copy()

# %%
titanic.Sex.value_counts()
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
titanic['Sex']=le.fit_transform(titanic.Sex)

# %%
titanic.Sex.value_counts()
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
cols.dtypes
# Out:
# Name    object
# dtype: object

# %%
titanic['Embarked']=le.fit_transform(titanic.Embarked)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket           int32
# Fare           float64
# Embarked         int64
# dtype: object

# %%
titanic['Ticket']=le.fit_transform(titanic.Ticket)

# %%
cat=['Sex','Ticket','Embarked']
for ob in cat:
    tit[ob]=le.fit_transform(tit[ob])
    
tit.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket           int64
# Fare           float64
# Embarked         int64
# dtype: object

# %% [markdown]
# # One hot encoding

# %%
titOH=titanic.copy()

# %%
objc=titOH.select_dtypes(include='object')
objc.nunique()
# Out:
# Name    891
# dtype: int64

# %%
import pandas as pd
titanic=pd.read_csv('C:/Users/TIMOH/Downloads/titanic_train (1).csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Age']=titanic['Age'].fillna(titanic['Age'].median())
titanic['Age'].isnull().sum()
# Out:
# 0

# %%
titanic['Embarked']=titanic['Embarked'].fillna(titanic['Embarked'].mode()[0])
titanic['Embarked'].isnull().sum()
# Out:
# 0

# %%
tit=titanic.drop('Cabin',1)
tit.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
titOH=tit.copy()

# %%
objc=titOH.select_dtypes(include='object')
objc.nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Embarked      3
# dtype: int64

# %%
#select columns with low cardinality
low=objc.loc[:,objc.nunique()<5]
low.columns
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
titH=pd.get_dummies(titOH,columns=low.columns)
titH.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
#
#       Ticket     Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0  A/5 21171   7.2500           0         1           0           0
# 1   PC 17599  71.2833           1         0           1           0
#
#    Embarked_S
# 0           1
# 1           0

# %%
# removing prefixes
titH=pd.get_dummies(titOH,columns=low.columns,prefix='',prefix_sep='')
titH.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
#
#       Ticket     Fare  female  male  C  Q  S
# 0  A/5 21171   7.2500       0     1  0  0  1
# 1   PC 17599  71.2833       1     0  1  0  0

# %%
titH.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Sex_female       uint8
# Sex_male         uint8
# Embarked_C       uint8
# Embarked_Q       uint8
# Embarked_S       uint8
# dtype: object
